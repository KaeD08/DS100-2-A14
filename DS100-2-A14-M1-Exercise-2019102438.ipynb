# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel("C:\\Users\\KRISTAN\\Documents\\heroes_data.xlsx")
pd.set_option('display.max_rows', None)
hero_data = data.loc[data['localized_name'].str.contains('Doom|Lifestealer|Abaddon|Weaver|Lich')]
hero_data
# Out:
#      Unnamed: 0   id                        name localized_name primary_attr  \
# 29           29   31          npc_dota_hero_lich           Lich          int
# 52           52   54  npc_dota_hero_life_stealer    Lifestealer          str
# 61           61   63        npc_dota_hero_weaver         Weaver          agi
# 67           67   69  npc_dota_hero_doom_bringer           Doom          str
# 100         100  102       npc_dota_hero_abaddon        Abaddon          str
#
#     attack_type                                              roles  \
# 29       Ranged                               ['Support', 'Nuker']
# 52        Melee  ['Carry', 'Durable', 'Jungler', 'Escape', 'Dis...
# 61       Ranged                                ['Carry', 'Escape']
# 67        Melee  ['Carry', 'Disabler', 'Initiator', 'Durable', ...
# 100       Melee                    ['Support', 'Carry', 'Durable']
#
#                                                   img  \
# ...

# %% [markdown]
# The whole data table for my DOTA 2 dataset, shows all the columns but are not visible, 5 rows (selected heroes) x 55 columns.

# %%
hero_data['Win Rate']=np.round((hero_data['turbo_wins']/hero_data['turbo_picks'])*100, 2)
hero_data
# Out:
# C:\Users\KRISTAN\AppData\Local\Temp\ipykernel_11344\844599634.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hero_data['Win Rate']=np.round((hero_data['turbo_wins']/hero_data['turbo_picks'])*100, 2)
#      Unnamed: 0   id                        name localized_name primary_attr  \
# 29           29   31          npc_dota_hero_lich           Lich          int
# 52           52   54  npc_dota_hero_life_stealer    Lifestealer          str
# 61           61   63        npc_dota_hero_weaver         Weaver          agi
# 67           67   69  npc_dota_hero_doom_bringer           Doom          str
# 100         100  102       npc_dota_hero_abaddon        Abaddon          str
#
# ...

# %% [markdown]
# Operation command for acquiring 'Public Matches Won'.

# %%
hero_data['Professional Ban Rate']=np.round((121//hero_data['pro_ban'])*10)
hero_data
# Out:
# C:\Users\KRISTAN\AppData\Local\Temp\ipykernel_11344\2835447514.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hero_data['Professional Ban Rate']=np.round((121//hero_data['pro_ban'])*10)
#      Unnamed: 0   id                        name localized_name primary_attr  \
# 29           29   31          npc_dota_hero_lich           Lich          int
# 52           52   54  npc_dota_hero_life_stealer    Lifestealer          str
# 61           61   63        npc_dota_hero_weaver         Weaver          agi
# 67           67   69  npc_dota_hero_doom_bringer           Doom          str
# 100         100  102       npc_dota_hero_abaddon        Abaddon          str
#
#     attack_type                                              roles  \
# ...

# %% [markdown]
# Operation command for acquiring 'Professional Matches Ban Rating'.

# %%
df1 = hero_data.loc[hero_data['localized_name'].str.contains('Doom|Lifestealer|Abaddon|Weaver|Lich')]
df1 = (df1.rename(columns={'localized_name':'Name','primary_attr': 'Prime Attribute','roles': 'Roles', 'main_role': 'Main Role', 'turbo_picks': 'Times Picked', 'turbo_wins': 'Times Won', 'pro_ban': 'Pro Times Banned', 'pro_win': 'Pro Times Won', 'pro_pick': 'Pro Times Picked'}))
df1 = df1.drop(columns=['name','attack_type','img','icon','base_health','base_health_regen','base_mana','base_mana_regen','base_armor','base_mr','base_attack_min','base_attack_max','base_str','base_agi','base_int','str_gain','agi_gain','int_gain','attack_range','projectile_speed','attack_rate','move_speed','turn_rate','cm_enabled','legs','hero_id','id','winrate','lane','1_pick','1_win','2_pick','2_win','3_pick','3_win','4_pick','4_win','5_pick','5_win','6_pick','6_win','7_pick','7_win','8_pick','8_win','lane','id'])
abs_data = df1
abs_data[['Name','Prime Attribute','Roles','Main Role','Times Picked', 'Times Won', 'Pro Times Banned', 'Pro Times Won', 'Pro Times Picked', 'Win Rate', 'Professional Ban Rate']]
# Out:
#             Name Prime Attribute  \
# 29          Lich             int
# 52   Lifestealer             str
# 61        Weaver             agi
# 67          Doom             str
# 100      Abaddon             str
#
#                                                  Roles     Main Role  \
# 29                                ['Support', 'Nuker']  hard_support
# 52   ['Carry', 'Durable', 'Jungler', 'Escape', 'Dis...      safelane
# 61                                 ['Carry', 'Escape']      safelane
# 67   ['Carry', 'Disabler', 'Initiator', 'Durable', ...       offlane
# 100                    ['Support', 'Carry', 'Durable']       support
#
#      Times Picked  Times Won  Pro Times Banned  Pro Times Won  \
# 29          20437       9886                25             33
# 52          25221      12518                50             23
# 61          42993      22220               146             52
# 67           9789       4156                54             15
# ...

# %% [markdown]
# Final and cleaned data table for my DOTA 2 dataset.

# %% [markdown]
# 2019102438
#
# Duran, Kristan C.
#
# The dataset that I have used is about DOTA 2, a world renowned pc game that transversed the gaming platform throughout the years, and peaks mostly in international competitions, meme video clip compilations, or even at the hands and minds of gaming content creators and streamers. The data set includes the 121 heroes of DOTA 2 (not updated at current patch of 123), along with other data such as the localized name, hero statistics, public matches picked, public matches won, winrate, win streaks, and the professional statistics of it. I utilized numpys, and pandas to manipulate and acquire data from these statistcis, such as the Professional Ban Rate, and Public Match Winrate, then I cleaned the necessary columns by purging those columns that are not to my liking, showing the final data table presented above.
